# %% [markdown]
# <a href="https://colab.research.google.com/github/lawrrey/COM-TEST-/blob/main/Hyper_Parameter_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.svm import SVC

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier

# %%
from xgboost import XGBClassifier

# %%
from lightgbm import LGBMClassifier

# %%
import os

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
dataset.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %%
dataset.shape
# Out:
# (2900, 8)

# %%
dataset.isna().sum()
# Out:
# Time_spent_Alone             63
# Stage_fear                   73
# Social_event_attendance      62
# Going_outside                66
# Drained_after_socializing    52
# Friends_circle_size          77
# Post_frequency               65
# Personality                   0
# dtype: int64

# %%
dataset['Time_spent_Alone'].fillna(dataset['Time_spent_Alone'].median(), inplace=True)

# %%
dataset['Stage_fear'].fillna(dataset['Stage_fear'].mode()[0], inplace=True)

# %%
dataset['Social_event_attendance'].fillna(dataset['Social_event_attendance'].median(), inplace=True)

# %%
dataset['Going_outside'].fillna(dataset['Going_outside'].median(), inplace=True)

# %%
dataset['Drained_after_socializing'].fillna(dataset['Drained_after_socializing'].mode()[0], inplace=True)

# %%
dataset['Friends_circle_size'].fillna(dataset['Friends_circle_size'].median(), inplace=True)

# %%
dataset['Post_frequency'].fillna(dataset['Post_frequency'].median(), inplace=True)

# %%
dataset['Personality'].fillna(dataset['Personality'].mode()[0], inplace=True)

# %%
dataset.isna().sum()
# Out:
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
label_enc = LabelEncoder()

# %%
dataset['Stage_fear'] = label_enc.fit_transform(dataset['Stage_fear'])

# %%
dataset['Drained_after_socializing'] = label_enc.fit_transform(dataset['Drained_after_socializing'])

# %%
dataset['Personality'] = label_enc.fit_transform(dataset['Personality'])

# %%
dataset.head()
# Out:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0           0                      4.0            6.0
# 1               9.0           1                      0.0            0.0
# 2               9.0           1                      1.0            2.0
# 3               0.0           0                      6.0            7.0
# 4               3.0           0                      9.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                          0                 13.0             5.0            0
# 1                          1                  0.0             3.0            1
# 2                          1                  5.0             2.0            1
# 3                          0                 14.0             8.0            0
# 4                          0                  8.0             5.0            0

# %%
X = dataset.drop('Personality', axis=1)

# %%
y = dataset['Personality']

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
models = {
    'LogisticRegression': {
        'model': LogisticRegression(),
        'params': {
            'C': [0.1, 1, 10],
            'solver': ['liblinear']
        }
    },
    'RandomForest': {
        'model': RandomForestClassifier(),
        'params': {
            'n_estimators': [50, 100],
            'max_depth': [None, 5],
            'min_samples_split': [2, 5]
        }
    },
    'SVC': {
        'model': SVC(),
        'params': {
            'C': [0.1, 1, 10],
            'kernel': ['linear', 'rbf']
        }
    },
    'KNN': {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [3, 5],
            'weights': ['uniform', 'distance']
        }
    },
    'NaiveBayes': {
        'model': GaussianNB(),
        'params': {}
    },
    'DecisionTree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'max_depth': [None, 3, 5],
            'min_samples_split': [2, 4]
        }
    },
    'GradientBoosting': {
        'model': GradientBoostingClassifier(),
        'params': {
            'n_estimators': [50, 100],
            'learning_rate': [0.01, 0.1],
            'max_depth': [3, 5]
        }
    },
    'AdaBoost': {
        'model': AdaBoostClassifier(),
        'params': {
            'n_estimators': [50, 100],
            'learning_rate': [0.5, 1.0]
        }
    },
    'XGBoost': {
        'model': XGBClassifier(eval_metric='logloss', use_label_encoder=False),
        'params': {
            'n_estimators': [50, 100],
            'learning_rate': [0.05, 0.1],
            'max_depth': [3, 5]
        }
    },
    'LightGBM': {
        'model': LGBMClassifier(verbose=-1),
        'params': {
            'n_estimators': [50, 100],
            'learning_rate': [0.05, 0.1],
            'max_depth': [3, 5, -1]
        }
    }
}

# %%
best_score = 0

# %%
best_model_name = None

# %%
best_model = None

# %%
for name, mp in models.items():
    clf = GridSearchCV(mp['model'], mp['params'], cv=3, scoring='accuracy', n_jobs=-1)
    clf.fit(X_train, y_train)

# %%
print(f"Model: {name}")
print(f"Best Parameters: {clf.best_params_}")
print(f"Best CV Accuracy: {clf.best_score_:.2f}\n")
# Out:
# Model: LightGBM
# Best Parameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# Best CV Accuracy: 0.94

# %%
if clf.best_score_ > best_score:
        best_score = clf.best_score_
        best_model_name = name
        best_model = clf.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
print(f"🔍 Best Model: {best_model_name}")
# Out:
# 🔍 Best Model: LightGBM

# %%
print("Classification Report:")
# Out:
# Classification Report:

# %%
print(classification_report(y_test, y_pred, target_names=['Extrovert', 'Introvert']))
# Out:
#               precision    recall  f1-score   support
#
#    Extrovert       0.94      0.92      0.93       302
#    Introvert       0.92      0.94      0.93       278
#
#     accuracy                           0.93       580
#    macro avg       0.93      0.93      0.93       580
# weighted avg       0.93      0.93      0.93       580
